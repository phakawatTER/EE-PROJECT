# %%
import pandas as pd
import model
import argparse
from tensorflow.keras.callbacks import History, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from sklearn import preprocessing
import os
import numpy as np
# Out:
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
epochs = 500
file_path = "training_set.csv"
checkpoint_file = "checkpoint.hdf5"
model_file = "model.h5"
val_split = 0.30
df = pd.read_csv(file_path)
dataset = df.values
y_train = df["load"].values  # training label
X_train = df[[col for col in df.columns if col != "load"]
             ].values  # training data

# %%
df
# Out:
#        load  norm_time  week_day     month
# 0     61.40   0.000000  0.142857  0.166667
# 1     61.70   0.128755  0.142857  0.166667
# 2     61.36   0.257511  0.142857  0.166667
# 3     61.43   0.386266  0.142857  0.166667
# 4     60.91   0.021459  0.142857  0.166667
# ...     ...        ...       ...       ...
# 9021  90.89   0.858369  0.857143  0.583333
# 9022  86.75   0.493562  0.857143  0.583333
# 9023  86.31   0.622318  0.857143  0.583333
# 9024  86.03   0.751073  0.857143  0.583333
# 9025  81.07   0.879828  0.857143  0.583333
#
# [9026 rows x 4 columns]

# %%
checkpoint = ModelCheckpoint(
    filepath=os.path.join("checkpoints", checkpoint_file), verbose=1, save_best_only=True, monitor="val_loss")
hist = History()
optimizer = Adam(0.001)
train_model = model.model()
train_model.compile(
    optimizer=optimizer, loss='mse', metrics=["accuracy"])
train_model.fit(X_train, y_train, validation_split=val_split, epochs=epochs, callbacks=[checkpoint, hist],
                batch_size=16)
train_model.save(os.path.join("models", model_file))
# Out:
# WARNING:tensorflow:From /opt/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /opt/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 6318 samples, validate on 2708 samples
# WARNING:tensorflow:From /opt/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/500
# 5584/6318 [=========================>....] - ETA: 0s - loss: nan - acc: 0.0000e+00
# Epoch 00001: val_loss did not improve from inf
# 6318/6318 [==============================] - 1s 130us/sample - loss: nan - acc: 0.0000e+00 - val_loss: nan - val_acc: 0.0000e+00
# Epoch 2/500
# 6240/6318 [============================>.] - ETA: 0s - loss: nan - acc: 0.0000e+00
# Epoch 00002: val_loss did not improve from inf
# 6318/6318 [==============================] - 1s 85us/sample - loss: nan - acc: 0.0000e+00 - val_loss: nan - val_acc: 0.0000e+00
# Epoch 3/500
# 6128/6318 [============================>.] - ETA: 0s - loss: nan - acc: 0.0000e+00
# Epoch 00003: val_loss did not improve from inf
# 6318/6318 [==============================] - 1s 85us/sample - loss: nan - acc: 0.0000e+00 - val_loss: nan - val_acc: 0.0000e+00
# Epoch 4/500
# 6176/6318 [============================>.] - ETA: 0s - loss: nan - acc: 0.0000e+00 ETA: 0s - loss: nan - acc: 0.0000
# Epoch 00004: val_loss did not improve from inf
# 6318/6318 [==============================] - 1s 97us/sample - loss: nan - acc: 0.0000e+00 - val_loss: nan - val_acc: 0.0000e+00
# Epoch 5/500
# 6144/6318 [============================>.] - ETA: 0s - loss: nan - acc: 0.0000e+00
# Epoch 00005: val_loss did not improve from inf
# 6318/6318 [==============================] - 1s 86us/sample - loss: nan - acc: 0.0000e+00 - val_loss: nan - val_acc: 0.0000e+00
# Epoch 6/500
# 5824/6318 [==========================>...] - ETA: 0s - loss: nan - acc: 0.0000e+00
# Epoch 00006: val_loss did not improve from inf
# 6318/6318 [==============================] - 1s 88us/sample - loss: nan - acc: 0.0000e+00 - val_loss: nan - val_acc: 0.0000e+00
# Epoch 7/500
# 5936/6318 [===========================>..] - ETA: 0s - loss: nan - acc: 0.0000e+00
# Epoch 00007: val_loss did not improve from inf
# 6318/6318 [==============================] - 1s 97us/sample - loss: nan - acc: 0.0000e+00 - val_loss: nan - val_acc: 0.0000e+00
# Epoch 8/500
#  880/6318 [===>..........................] - ETA: 0s - loss: nan - acc: 0.0000e+00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-487460e6aabd> in <module>
#       7     optimizer=optimizer, loss='mse', metrics=["accuracy"])
#       8 train_model.fit(X_train, y_train, validation_split=val_split, epochs=epochs, callbacks=[checkpoint, hist],
# ----> 9                 batch_size=16)
#      10 train_model.save(os.path.join("models", model_file))
#
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, max_queue_size, workers, use_multiprocessing, **kwargs)
#     878           initial_epoch=initial_epoch,
#     879           steps_per_epoch=steps_per_epoch,
# --> 880           validation_steps=validation_steps)
#     881
#     882   def evaluate(self,
#
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/keras/engine/training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, mode, validation_in_fit, **kwargs)
#     327
#     328         # Get outputs.
# --> 329         batch_outs = f(ins_batch)
#     330         if not isinstance(batch_outs, list):
#     331           batch_outs = [batch_outs]
#
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3035     inputs = nest.flatten(inputs)
#    3036
# -> 3037     session = get_session()
#    3038     feed_arrays = []
#    3039     array_vals = []
#
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/keras/backend.py in get_session()
#     479   session = _get_session()
#     480   if not _MANUAL_VAR_INIT:
# --> 481     with session.graph.as_default():
#     482       _initialize_variables(session)
#     483   return session
#
# /opt/anaconda3/envs/tf/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in get_controller(self, default)
#    5250     try:
#    5251       with super(_DefaultGraphStack, self).get_controller(
# -> 5252           default) as g, context.graph_mode():
#    5253         yield g
#    5254     finally:
#
# /opt/anaconda3/envs/tf/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# KeyboardInterrupt:
